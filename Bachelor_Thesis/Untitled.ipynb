# %%
# %run main.py
# Out:
# ...
#    THESIS PIPELINE: NEUTRON STAR EOS INFERENCE ORCHESTRATOR
# ...
# --- Phase 0: Calculating Hadronic Baselines ---
#   > MDI-1     : 1.967 M_sun
#   > MDI-2     : 1.979 M_sun
#   > MDI-3     : 2.009 M_sun
#   > MDI-4     : 2.018 M_sun
#   > NLD       : 2.023 M_sun
#   > HHJ-1     : 1.937 M_sun
#   > HHJ-2     : 2.087 M_sun
#   > Ska       : 2.219 M_sun
#   > SkI4      : 2.205 M_sun
#   > HLPS-2    : 2.498 M_sun
#   > HLPS-3    : 2.990 M_sun
#   > SCVBB     : 1.980 M_sun
#   > WFF-1     : 2.118 M_sun
#   > WFF-2     : 2.188 M_sun
#   > W         : 2.607 M_sun
#   > BGP       : 2.376 M_sun
#   > BL-1      : 2.082 M_sun
#   > BL-2      : 1.967 M_sun
#   > DH        : 2.045 M_sun
#   > APR-1     : 2.378 M_sun
#
# [INFO] Found existing dataset: data\thesis_dataset.csv
# [INFO] Schema validation passed. Loaded 763496 samples.
#
# --- Training Hierarchy of Random Forest Models ---
# [Info] Dropped 14331 low-mass stars (NaN features) to ensure fair model comparison.
# ...
